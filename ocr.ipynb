# %%
from inference_sdk import InferenceHTTPClient
import cv2
import json
from paddleocr import PaddleOCR

# %%
CLIENT = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="0CF8GEPLUoqsxGo89vaZ"
)

# %%
# Load your image
image_path = "../gc.jpg"   


# infer on a local image
result = CLIENT.infer(image_path, model_id="card-fields-extraction-w46qc/1")

# %%
ocr = PaddleOCR(use_textline_orientation = True , lang='ar')
# Out:
# UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\khali\.paddlex\official_models\PP-LCNet_x1_0_doc_ori`.
# Creating model: ('UVDoc', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\khali\.paddlex\official_models\UVDoc`.
# Creating model: ('PP-LCNet_x1_0_textline_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\khali\.paddlex\official_models\PP-LCNet_x1_0_textline_ori`.
# Creating model: ('PP-OCRv5_server_det', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\khali\.paddlex\official_models\PP-OCRv5_server_det`.
# Creating model: ('arabic_PP-OCRv5_mobile_rec', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `C:\Users\khali\.paddlex\official_models\arabic_PP-OCRv5_mobile_rec`.

# %%
image = cv2.imread(image_path)
i =1
for pred in result["predictions"]:
    x1 = int(pred["x"] - pred["width"] / 2)
    x2 = int(pred["x"] + pred["width"] / 2)
    
    y1 = int(pred["y"] - pred["height"] / 2)
    y2 = int(pred["y"] + pred["height"] / 2)

    # label = f"{pred["class"]}: {pred["confidence"]:.2f}"
    print(x1 , x2 , y1 , y2)


    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
    # cv2.putText(image , label, (x1, y1-10),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    # cv2.imwrite(f'./test{i}.png' , image[y1:y2 , x1:x2])

    crop = image[y1:y2 , x1:x2]

    rr = ocr.predict(crop)
    
    for res in rr:
        res.print()
        cv2.imwrite(f"output{i}.png", crop)

        data = res.json  # or res.to_json() depending on version
    
    with open(f"output{i}.json", "w") as f:
        json.dump(data, f, indent=4)
        # res.save_to_image(f"output{i}")
    i = i + 1


    

    # cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
output = "./res.png"
cv2.imwrite(output , image)
# cv2.imwrite('hh.png' , image[636:906 , 476:530])

# from paddleocr import PaddleOCR

# # Basic initialization parameters remain the same
# ocr = PaddleOCR(lang="en")
# result = ocr.ocr(image_path)
# # Or use the new unified interface
# # result = ocr.predict("img.png")
# for res in result:
#     # Directly print recognition results, no nested loops required
#     res.print()

# # Visualization and saving results are simpler
# res.save_to_img("res")
# Out:
# 368 535 453 502
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 0}, 'dt_polys': array([[[20,  7],
#         ...,
#         [18, 39]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['مبارة خاصة'], 'rec_scores': array([0.8729974]), 'rec_polys': array([[[20,  7],
#         ...,
#         [18, 39]]], dtype=int16), 'rec_boxes': array([[18, ..., 45]], dtype=int16)}}
# 63 296 461 507
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 180}, 'dt_polys': array([[[14,  7],
#         ...,
#         [14, 39]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([1]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['JT1VOLJ7309011326'], 'rec_scores': array([0.99479449]), 'rec_polys': array([[[14,  7],
#         ...,
#         [14, 39]]], dtype=int16), 'rec_boxes': array([[14, ..., 39]], dtype=int16)}}
# 362 540 149 222
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 0}, 'dt_polys': array([[[106,  14],
#         ...,
#         [108,  53]],
#
#        [[ 35,  24],
#         ...,
#         [ 39,  63]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0, 0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['نضال', 'نصيبي'], 'rec_scores': array([0.99761689, 0.98121274]), 'rec_polys': array([[[106,  14],
#         ...,
#         [108,  53]],
#
#        [[ 35,  24],
#         ...,
#         [ 39,  63]]], dtype=int16), 'rec_boxes': array([[106, ...,  53],
#        [ 35, ...,  63]], dtype=int16)}}
# 309 458 539 584
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 0}, 'dt_polys': array([[[15,  6],
#         ...,
#         [15, 40]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['1989/04/21'], 'rec_scores': array([0.99786139]), 'rec_polys': array([[[15,  6],
#         ...,
#         [15, 40]]], dtype=int16), 'rec_boxes': array([[15, ..., 40]], dtype=int16)}}
# 407 576 264 327
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 90}, 'dt_polys': array([[[ 12,   0],
#         ...,
#         [ 17, 146]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['فوي  ويوية'], 'rec_scores': array([0.3823697]), 'rec_polys': array([[[ 12,   0],
#         ...,
#         [ 17, 146]]], dtype=int16), 'rec_boxes': array([[ 12, ..., 146]], dtype=int16)}}
# 381 625 579 634
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 180}, 'dt_polys': array([[[41, 14],
#         ...,
#         [39, 44]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': [''], 'rec_scores': array([0.]), 'rec_polys': array([[[41, 14],
#         ...,
#         [39, 44]]], dtype=int16), 'rec_boxes': array([[39, ..., 49]], dtype=int16)}}
# 337 466 354 416
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 0}, 'dt_polys': array([[[21, 15],
#         ...,
#         [22, 50]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['09632960'], 'rec_scores': array([0.99968886]), 'rec_polys': array([[[21, 15],
#         ...,
#         [22, 50]]], dtype=int16), 'rec_boxes': array([[21, ..., 50]], dtype=int16)}}
# 5 61 50 622
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 270}, 'dt_polys': array([[[147,  11],
#         ...,
#         [148,  50]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['تونسر'], 'rec_scores': array([0.87446392]), 'rec_polys': array([[[147,  11],
#         ...,
#         [148,  50]]], dtype=int16), 'rec_boxes': array([[147, ...,  50]], dtype=int16)}}
# 63 188 516 559
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 180}, 'dt_polys': array([[[21,  6],
#         ...,
#         [21, 39]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['YIOAO'], 'rec_scores': array([0.41985112]), 'rec_polys': array([[[21,  6],
#         ...,
#         [21, 39]]], dtype=int16), 'rec_boxes': array([[21, ..., 39]], dtype=int16)}}
# 308 454 497 543
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': True}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': True}, 'angle': 180}, 'dt_polys': array([[[ 0,  1],
#         ...,
#         [ 0, 42]]], dtype=int16), 'text_det_params': {'limit_side_len': 64, 'limit_type': 'min', 'thresh': 0.3, 'max_side_limit': 4000, 'box_thresh': 0.6, 'unclip_ratio': 1.5}, 'text_type': 'general', 'textline_orientation_angles': array([0]), 'text_rec_score_thresh': 0.0, 'return_word_box': False, 'rec_texts': ['WA٨٦٤L'], 'rec_scores': array([0.46070194]), 'rec_polys': array([[[ 0,  1],
#         ...,
#         [ 0, 42]]], dtype=int16), 'rec_boxes': array([[ 0, ..., 42]], dtype=int16)}}
# True
